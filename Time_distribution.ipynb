# %%
import matplotlib.pyplot as plt
from utils.invoice_utils import extract_worked_hour_as_df, plot_weekly_hour_distribution
plt.rcParams["figure.figsize"] = (12,8)

# %%
company_data = {'name':'CompanyName'}
month = 6
year = 2022
df,total_hours =extract_worked_hour_as_df(month,year,company_data['name'],drop_date_from_beginning_end=False)

# %%
plot_weekly_hour_distribution(df)
